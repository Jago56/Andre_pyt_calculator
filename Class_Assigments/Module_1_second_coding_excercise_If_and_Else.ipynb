# %% [markdown]
# <a href="https://colab.research.google.com/github/Jago56/Andre_pyt_calculator/blob/main/Class_Assigments/Module_1_second_coding_excercise_If_and_Else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **Write a program to check whether a given number is a three-digit number or not.**

# %%
num = int(input('Enter you number:'))
if '3' in str(num):
    print('The entered number is a three digit number',num)
else:
    print('The entered number is NOT a three digit number', num)
# Out:
# Enter you number:1222
# The entered number is NOT a three digit number 1222

# %% [markdown]
# Write a program to compare two numbers and print the larger number.

# %%
num1 = int(input('Enter you first number:'))
num2 = int(input('Enter your second number:'))

if num1 >= num2:
   print(num1)
else:
   print(num2)
# Out:
# Enter you first number:10
# Enter your second number:30
# 30

# %% [markdown]
# Write a program to check if a given number is prime or not (assume the number > 1).

# %% [markdown]
# for i in range(2, num):
#     if num % i == 0:
#         is_prime = False
#         break

# %%
num = int(input('Please enter your number:'))
is_prime = True

for i in range(2, num):
 # Does i divide num evenly?
  if num % i == 0:
    is_prime = False
    break
if is_prime:
    print(num , 'is a prime number')
else:
    print(num, 'is NOT a prime number')
# Out:
# Please enter your number:8
# 8 is NOT a prime number

# %% [markdown]
# Ask the user to enter a number
# num = float(input("Enter a number: "))
#
# # Manually compute the absolute value
# if num < 0:
#     absolute_value = -num
# else:
#     absolute_value = num
#
# # Display the result
# print("The absolute value is:", absolute_value)
#
# Write a program to print the absolute value of a given number (e.g., -5 → 5).

# %%
try:
    num_str = input('Please enter your number:')
    if num < 0:
      absolute_value = -num
      print('The absolute value of your number is:', absolute_value)
    else:
      absolute_value = num
      print('The absolute value of your number is:', absolute_value)
except ValueError:
    print("Please enter a valid number.")
# Out:
# Please enter your number:7
# The absolute value of your number is: 1222

# %% [markdown]
# Write a program to check if a number is divisible by 2 or 3.
# Examples that WILL print divisible: 2, 3, 4, 6, 8, 9, 10, 12, 14, 15, 16, 18…
# Examples that will NOT print divisible: 5, 7, 11, 13, 17

# %%
#n = int(input('Enter your number'))
#if n % 2 == 0 or n % 3 == 0:
 # print(f"{n} is divisible by 2 or 3.")
#else:
 # print(f"{n} is NOT divisible by 2 or 3.")

# %%
try:
    n = int(input('Enter your number: '))
    if n % 2 == 0 or n % 3 == 0:
        print('Your entered number is divisible by 2 or 3.')
    else:
        print('Your entered number is NOT divisible by 2 or 3.')

except ValueError:
    print("Please enter a valid number.")
# Out:
# Enter your number: HELLO
# Please enter a valid number.

# %%
num = float(input('Please enter your number: '))

if num < 0:
       absolute_value = -num
       print('The absolute value of your number is:', absolute_value)
else:
        absolute_value = num
#       print('The absolute value of your number is:', absolute_value)
# Out:
# Please enter your number: -5
# The absolute value of your number is: 5.0

# %% [markdown]
# error handling

# %%
try:
    num = float(input('Please enter your number: '))

    if num < 0:
        absolute_value = -num
        print('The absolute value of your number is:', absolute_value)
    else:
        absolute_value = num
        print('The absolute value of your number is:', absolute_value)

except ValueError:
    print("Please enter a valid number.")
# Out:
# Please enter your number: ttttt
# Please enter a valid number.

# %%
with open("example.txt", "w", encoding="utf-8") as file:
    file.write("Hello, Andre!\n")
    file.write("This is your first file.\n")
