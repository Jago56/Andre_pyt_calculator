# %% [markdown]
# <a href="https://colab.research.google.com/github/Jago56/Andre_pyt_calculator/blob/main/Class_Assignments/Module_1_coding_first_excercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#
# *   Print the first and last colors from the list.
# *   Replace the third color with a new one.

# %%
#Create a list of your favorite colors.
#Print the first and last colors from the list.
#Replace the third color with a new one.
Colors = ['Red', 'Green', 'Blue','Black']
#print the first color
print('The first color' , Colors[0])
#print the second color
#print('The first color' , Colors[-1])
# Out:
# The first color Red
# The first color Black

# %%
# replace the 3 (index)
Colors[3] = 'Purple'
print(Colors)
# Out:
# ['Red', 'Green', 'Blue', 'Purple']

# %% [markdown]
# Write a program to create a list of numbers from 10 to 50 in steps of 5.
# o Remove all odd numbers from the list.
# o Reverse the list and display it. **bold text**

# %%
#creat a list
L1 = list(range(10, 51,5))
print(L1)
# Out:
# [10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
# remove all odd numbers
result = L1[::2]
print(result)
# Out:
# [10, 20, 30, 40, 50]

# %%
#revese the list
result.reverse()
print(result)
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# **Imagine you are planning a trip. Create a list of 5 cities you'd like to visit.**
#  Add one more city to the list at the second position.
# Remove the last city from the list.
# Sort the list in alphabetical order.

# %%
# create a list of 5 cities
L1 = ['Boston','Los Angeles', 'Atlanta','Chicago', 'New York']
# add a city a position 2 - index 2
L1[2] = 'Hawaii'
print(L1)
# Out:
# ['Boston', 'Los Angeles', 'Hawaii', 'Chicago', 'New York']

# %%
L1.pop()
print(L1)
# Out:
# ['Boston', 'Los Angeles', 'Hawaii', 'Chicago']

# %%
L1.sort()
print(L1)
# Out:
# ['Boston', 'Chicago', 'Hawaii', 'Los Angeles']

# %% [markdown]
# Create a dictionary with the names of three countries as keys and their capitals as
# values. **bold text**

# %%
Countries = {'Nigeria': 'Abuja', 'Brazil' : 'Brasilia', 'France': 'Marseille', 'Sweden' :'Stockholm'}
Countries['Sweden'] = 'Austraila'

# %%
print(Countries)
# Out:
# {'Nigeria': 'Abuja', 'Brazil': 'Brasilia', 'France': 'Marseille', 'Sweden': 'Austraila'}

# %%
del Countries['Nigeria']

# %%
print(Countries)
# Out:
# {'Brazil': 'Brasilia', 'France': 'Marseille', 'Sweden': 'Austraila'}

# %% [markdown]
# You are managing a shop. Create a dictionary with three items as keys and their
# prices as values.
#  Add a new item and its price.
#  Find the total price of all items.
#  Check if a specific item (e.g., "Milk") exists in the dictionary.

# %%
Groceries = {'Milk': 4.00, 'Bread': 3.50,'Eggs': 4.00}
Groceries['Sasauge'] = 3.00
print(Groceries)
# Out:
# {'Milk': 4.0, 'Bread': 3.5, 'Eggs': 4.0, 'Sasauge': 3.0}

# %%
#Find the total price of all items
sum = sum(Groceries.values())

# %%
print(sum)
# Out:
# 14.5

# %%
#checking for Milk in the list
Groceries.items()
# Out:
# dict_items([('Milk', 4.0), ('Bread', 3.5), ('Eggs', 4.0), ('Sasauge', 3.0)])

# %% [markdown]
#  Create a dictionary for a student’s details: name, age, and a list of three favorite
# subjects.
#  Add a new subject to the list of favorite subjects.
#  Update the student's age.
#  Display all keys and values in the dictionary.

# %%
Students = {'Chadd': {'age': 16, 'Favorite_Subjects': ['Spanish','Literature','History']},'Andre': {'age':15, 'Favorite_Subjects': ['Math','Geography','History']},
'Tanya': {'age' : 16, 'Favorite_Subjects': ['Spanish','Literature','History']}}
Students.items()
# Out:
# dict_items([('Chadd', {'age': 16, 'Favorite_Subjects': ['Spanish', 'Literature', 'History']}), ('Andre', {'age': 15, 'Favorite_Subjects': ['Math', 'Geography', 'History']}), ('Tanya', {'age': 16, 'Favorite_Subjects': ['Spanish', 'Literature', 'History']})])

# %%
Students = {
    'Chadd' : {'age': 16, 'Favorite_Subjects': ['Spanish', 'Literature', 'History']},
    'Andre' : {'age': 15, 'Favorite_Subjects': ['Math', 'Geography', 'History']},
    'Tanya' : {'age': 16, 'Favorite_Subjects': ['Spanish', 'Literature', 'History']}
}
Students['Chadd']['age'] = 17
Students['Andre']['age'] = 16
Students['Tanya']['age'] = 18
print(Students)
# Out:
# {'Chadd': {'age': 17, 'Favorite_Subjects': ['Spanish', 'Literature', 'History']}, 'Andre': {'age': 16, 'Favorite_Subjects': ['Math', 'Geography', 'History']}, 'Tanya': {'age': 18, 'Favorite_Subjects': ['Spanish', 'Literature', 'History']}}

# %%
Students.items()
# Out:
# dict_items([('Chadd', {'age': 17, 'Favorite_Subjects': ['Spanish', 'Literature', 'History']}), ('Andre', {'age': 16, 'Favorite_Subjects': ['Math', 'Geography', 'History']}), ('Tanya', {'age': 18, 'Favorite_Subjects': ['Spanish', 'Literature', 'History']})])

# %% [markdown]
# # You have two groups of friends who like different activities:
# group_a = {"cycling", "hiking", "swimming"}
# group_b = {"swimming", "painting", "hiking"}

# %%
group_a = {"cycling", "hiking", "swimming"}
group_b = {"swimming", "painting", "hiking"}
# intersecton:https://www.google.com/search?q=how+to+compare+to+sets+in+python&rlz=1C1HKFL_enUS1201US1201&oq=how+to+compare+to+sets+in+python&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIICAEQABgWGB4yCAgCEAAYFhgeMggIAxAAGBYYHjIICAQQABgWGB4yCAgFEAAYFhgeMggIBhAAGBYYHjIICAcQABgWGB4yCAgIEAAYFhgeMggICRAAGBYYHtIBCTEyMTgwajBqNKgCA7ACAfEFhlwgNX3SgDXxBYZcIDV90oA1&sourceid=chrome&ie=UTF-8https://www.google.com/search?q=how+to+compare+to+sets+in+python&rlz=1C1HKFL_enUS1201US1201&oq=how+to+compare+to+sets+in+python&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIICAEQABgWGB4yCAgCEAAYFhgeMggIAxAAGBYYHjIICAQQABgWGB4yCAgFEAAYFhgeMggIBhAAGBYYHjIICAcQABgWGB4yCAgIEAAYFhgeMggICRAAGBYYHtIBCTEyMTgwajBqNKgCA7ACAfEFhlwgNX3SgDXxBYZcIDV90oA1&sourceid=chrome&ie=UTF-8
activities = group_a & group_b
print(activities)
#only things in group a
only_group_a = group_a - group_b
print(only_group_a)
# Out:
# {'swimming', 'hiking'}
# {'cycling'}

# %%
# Combine both groups’ activities into one set.
all_activities = group_a | group_b
print(all_activities)
# Out:
# {'swimming', 'cycling', 'painting', 'hiking'}

# %% [markdown]
# Create a set of 5 numbers.
# Add two new numbers to the set.
# Remove one number from the set.
# # Check if the number 10 is in the set. **bold text**

# %%
#create a set
set1  = {10,20,30,40,50}
#add one number to the set
set1.add('60')
print(set1)
#add second number to the set
set1.add('70')
print(set1)
# Out:
# {50, 20, '60', 40, 10, 30}
# {'70', 50, 20, '60', 40, 10, 30}

# %% [markdown]
# Create a tuple of 5 animal names.
# Print the first and the last animal in the tuple.
# # Try to add a new animal to the tuple. What happens? **bold text**

# %%
#Create a tuple with 5 animal name
tup1 = 'Dog', 'Cat', 'Bird', 'Lion', 'Giraffe'
type(tup1)
first_animal = tup1[0]
#print first animal
print(first_animal)
#print second_animal
second_animal = tup1[-1]
print(second_animal)
print(tup1)
# Out:
# Dog
# Giraffe
# ('Dog', 'Cat', 'Bird', 'Lion', 'Giraffe')

# %% [markdown]
# Write a program to swap the values of two tuples:
# tuple_a = (1, 2, 3)
# tuple_b = (4, 5, 6)

# %%
#create two tuples
tuple_a = 1,2,3
tuple_b = 10,20,30
#swap tuples
tuple_a, tuple_b = tuple_b, tuple_a
print("Tuple_a:", tuple_a)
print('Tuple_b:',tuple_b)
# Out:
# Tuple_a: (10, 20, 30)
# Tuple_b: (1, 2, 3)

# %%
d1 = {1 : 'orange',
      2 : 'Mango',
      3 : 'Apple',
      4 : 'Banana'}
print(d1)
# Out:
# {1: 'orange', 2: 'Mango', 3: 'Apple', 4: 'Banana'}

# %%
d1[1]
# Out:
# 'orange'

# %%
d1.keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
d1.values()
# Out:
# dict_values(['orange', 'Mango', 'Apple', 'Banana'])

# %% [markdown]
# Create a tuple to store information about a book (title, author, price).
#  Unpack the tuple into three variables.
#  Use one of the variables to display the price of the book.

# %%
# create a tuple with information about a book
book = ('A Practical Introduction to Python 3' , 'Dan Bader, Joanna Jablonski, Fletcher Heisler', 17.53)
#unpack the tuple into three variables
title, authors, price = book
# display the variable price
# display the price of the book
# display the title of the book
# display the author(s) of the book
print('The price of the book is:', price)
print('The title of the book is:', title)
print('the authors of the book are:', author)
# Out:
# The price of the book is: 17.53
# The title of the book is: A Practical Introduction to Python 3
# the authors of the book are: Dan Bader, Joanna Jablonski, Fletcher Heisler
